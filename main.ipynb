# %%
from functions import (
    generate_data_serieses,
    generate_line_sereis,
    arrange_series,
    accumulate_series,
    transform_series,
    normalise_series,
    normalise_factor,
)
import numpy as np
from random import random
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
size = 1024
x=np.arange(size)

serieses = []
lines = []
for _ in range(20):
    
    pos_series, neg_series = generate_data_serieses(size)
    series = arrange_series(pos_series, neg_series)
    series = accumulate_series(series)
    m = random() * 0.1
    c = random() * 0.1
    line = generate_line_sereis(m, c, len(series))
    series = transform_series(series, line)
    
    nf = normalise_factor(series)
    serieses.append(normalise_series(series))
    lines.append((line - nf.min)/nf.factor)

# %%
fig = make_subplots(4, 5)

for i in range(4):
    for j in range(5):
        fig.append_trace(go.Scatter(x=x, y=serieses[4*i + j]), row=i+1, col=j+1)
        fig.append_trace(go.Line(x=x, y=lines[4*i + j]), row=i+1, col=j+1)

fig.update_layout(height=600, width=800, showlegend=False)
fig.show()
# Out:
# /Users/tangchiuyat/Library/Caches/pypoetry/virtualenvs/ml-regression-lab-3aCdUF2l-py3.11/lib/python3.11/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
